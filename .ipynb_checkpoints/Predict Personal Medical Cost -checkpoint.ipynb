# %%
import pandas as pd
import seaborn as sns

# %%
sns.set_palette("Accent")
sns.set_style("darkgrid")

# %%
df = pd.read_csv('./data/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.groupby('region')['region'].count()
# Out:
# region
# northeast    324
# northwest    325
# southeast    364
# southwest    325
# Name: region, dtype: int64

# %%
df.groupby('smoker')['smoker'].count()
# Out:
# smoker
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
def lambda_region(x):
    if x == 'northeast':
        return 0
    if x == 'northwest':
        return 1 
    if x == 'southeast':
        return 2
    else:
        return 3

# %%
df['binario_smoker'] = df['smoker'].apply(lambda x: 1 if x == 'yes' else 0)
df['binario_sex'] = df['sex'].apply(lambda x: 1 if x == 'female' else 0)
df['binario_region'] = df['region'].apply(lambda_region)
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  \
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#    binario_smoker  binario_sex  binario_region
# 0               1            1               3
# 1               0            0               2
# 2               0            0               2
# 3               0            0               1
# 4               0            0               1

# %%
df.corr()
# Out:
#                      age       bmi  children   charges  binario_smoker  \
# age             1.000000  0.109272  0.042469  0.299008       -0.025019
# bmi             0.109272  1.000000  0.012759  0.198341        0.003750
# children        0.042469  0.012759  1.000000  0.067998        0.007673
# charges         0.299008  0.198341  0.067998  1.000000        0.787251
# binario_smoker -0.025019  0.003750  0.007673  0.787251        1.000000
# binario_sex     0.020856 -0.046371 -0.017163 -0.057292       -0.076185
# binario_region  0.002127  0.157566  0.016569 -0.006208       -0.002181
#
#                 binario_sex  binario_region
# age                0.020856        0.002127
# bmi               -0.046371        0.157566
# children          -0.017163        0.016569
# charges           -0.057292       -0.006208
# binario_smoker    -0.076185       -0.002181
# binario_sex        1.000000       -0.004588
# binario_region    -0.004588        1.000000

# %%
ax = sns.boxplot(data=df['charges'])

# %%
ax = sns.histplot(data = df['charges'])

# %%
ax = sns.pairplot(data=df)

# %%
import numpy as np

# %%
np.log(0)
# Out:
# C:\Users\vitor\AppData\Local\Temp\ipykernel_10624\2933082444.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# -inf

# %%
df['log_age'] = np.log(df['age'])
df['log_bmi'] = np.log(df['bmi'])
df['log_charges'] = np.log(df['charges'])
df['log_binario_smoker'] =  np.log(df['binario_smoker'] + 1)
df['log_region'] = np.log(df['binario_region'] + 1)

# %%
df.head(16)
# Out:
#     age     sex     bmi  children smoker     region      charges  \
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
ax = sns.histplot(data=df['log_charges'])

# %%
df.corr()
# Out:
#                          age       bmi  children   charges  binario_smoker  \
# age                 1.000000  0.109272  0.042469  0.299008       -0.025019
# bmi                 0.109272  1.000000  0.012759  0.198341        0.003750
# children            0.042469  0.012759  1.000000  0.067998        0.007673
# charges             0.299008  0.198341  0.067998  1.000000        0.787251
# binario_smoker     -0.025019  0.003750  0.007673  0.787251        1.000000
# binario_sex         0.020856 -0.046371 -0.017163 -0.057292       -0.076185
# binario_region      0.002127  0.157566  0.016569 -0.006208       -0.002181
# log_age             0.986326  0.102185  0.090605  0.289967       -0.022613
# log_bmi             0.116146  0.991023  0.013058  0.199266        0.000366
# log_charges         0.527834  0.132669  0.161336  0.892964        0.665506
# log_binario_smoker -0.025019  0.003750  0.007673  0.787251        1.000000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['log_charges']

# %%
X = df[['log_age', 'log_bmi', 'log_binario_smoker']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=2811)

# %%
from sklearn.linear_model import LinearRegression

# %%
ml1 = LinearRegression()

# %%
ml1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
ml1.score(X_test, y_test)
# Out:
# 0.7627881252275003
